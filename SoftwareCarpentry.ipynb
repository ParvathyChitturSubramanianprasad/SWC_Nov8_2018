# %% [markdown]
# ## Software Carpentry November 2018

# %% [markdown]
# This is text line breaks do not matter.
#
# Get new line using blank one.

# %% [markdown]
# * item 1
# * item 2

# %% [markdown]
# 1. Item 1
# 5. Item 2
# 3. Item 3

# %% [markdown]
# [mylink](https://www.google.com)

# %% [markdown]
# Square for hyperlink and brackets for link address

# %%
from IPython.display import Image
Image(filename = 'C:/Users/parva/Desktop/Ganapathy.jpg')

# %% [markdown]
# ## Equations - Latex style

# %%
age = 30
first_name = 'Parvathy'
print('Age:',age)
print('Frist Name:',first_name)
# Out:
# Age: 30
# Frist Name: Parvathy

# %%
last_name = 'Chittur Subramanianprasad'
name = first_name + last_name

# %%
print(name)
# Out:
# ParvathyChittur Subramanianprasad

# %%
name[0:4]
# Out:
# 'Parv'

# %%
print(len(name),
len(first_name)
# Out:
# 8
